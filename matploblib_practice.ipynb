# %%
# %matplotlib inline

# %%
pip install fontstyle

# %%
#Import dependencies
import matplotlib.pyplot as plt

# %%
#Set x-axis to a list of strings for each month
x_axis = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

#Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.plot(x_axis, y_axis)
plt.xlabel("Date")
plt.ylabel("Savings($)")
plt.title('Savings Account Results')
plt.show()

# %%
#Create the plot and add a label for the legend
plt.plot(x_axis, y_axis, marker="D", color="green", linewidth=2, label='Boston',)
#Create labels for the x and yaxes 
plt.xlabel("Date")
plt.ylabel("Fare($)")
#Set the y limit between 0 and 45
plt.ylim(0, 45)
# Create a title
plt.title("PyBer Fare by Month")
#Add a grid
plt.grid()
# Add the legend
plt.legend()

#if you want to change 
#the figure size to 20 pixels wide by 10 pixels high do plt.figure(figsize=(20,10)) or 
#plt.subplots(figsize=(20,10))

# %%
#Create the plot - this creates a figure with current axes, or labels  - create with ax.plt()
#plt.subplots() #returns a tuple containing a figure and axes object
#fig, ax.plot = plt.subplots (x_axis, y_axis) unpacks the tuple into variables fig and ax
#fig the first variable means figure
#ax the second variable means axes of the figure that allows us to annotate the figure
#the ax.plot(x_axis, y_axis) plots the data from the x and y axes 
#The fig, ax = plt.subplots() line of code can also be written like this 
#fig = plt.figure() # to change figure level attributes like axis labels title or legend 
#ax = plt.axes()
#ax.plot(x_axis, y_axis)
#plt.show()

# %%
#set the x-axis to a list of strings for each month
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

#set the y-axis to a list of floats at the total fare in US dollars accumulated for each month
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09 ]

# %%
#Create the plot
plt.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
#Create the plot
plt.bar(x_axis, y_axis, color="green", label='Boston')

#Create labels for the x and y axes
plt.xlabel("Date")
plt.ylabel("Fare($)")

#Create a title
plt.title("PyBer Fare by Month")

#Add the legend
plt.legend()

# %%
#Lets create a horizontal bar chart to display the music groups among teens, number of votes by county
plt.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
#If we want the data on opposite axes, switch the arguments in the barh() function  but this no good
plt.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
#Lets switch back because that is the best way to represent the data to convey each months average fare
#Create the plot to have y-axis to have the months in ascending order, using gca() method to get current axes
plt.barh(x_axis, y_axis)
plt.gca().invert_yaxis()

# %%
#Create the plot
plt.barh(x_axis, y_axis, color="magenta", label='Boston')
plt.gca().invert_yaxis()
#Create labels for the x and y axes
plt.xlabel("Date")
plt.ylabel("Fare($)")

#Create a title
plt.title("PyBer Fare by Month")

#Add the legend
plt.legend()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
#Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis, color="k", label='New York')
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Out:
# Text(0, 0.5, 'Fare($)')

# %%
#Create a horizontal bar chart using object-oriented interface method (ax.barh) with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
#Create the plot with ax.plt() to switch arguments in the barh() function
fig, ax = plt.subplots()
ax.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
fig, ax = plt.subplots()
# Set the x-axis to a list of strings for each month.
y_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
x_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

ax.barh(y_axis, x_axis, color="cyan", label ='Chicago')
plt.xlabel("Fare($)")
plt.ylabel("Date")
plt.gca().invert_yaxis()
plt.title("PyBer Fare by Month")
plt.legend()

# %%
#Import dependencies library
import matplotlib.pyplot as plt

# %%
x = [50, 42, 39, 34, 32, 48, 22, 17, 8, 13]
y = [17, 19, 21, 22, 24, 23, 34, 31, 43, 35]

# %%
plt.scatter(x,y, c ='green', marker='x', s=x)
plt.xlabel('Total Number of Rise (Per City)')
plt.ylabel('Average Fare($)')
plt.title('Average Fare vs Total Rides')
plt.show()

# %%
# set the x-axis to a list of strings for each month
x_axis = ["Jan", "Feb", "Mar", "Apr", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

#Set the y-axis to a list of floats as the total fare in US dollars is accumulated for each month
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
#Creating a scatter plot
plt.plot(x_axis, y_axis, 'o')

# %%
# set the x-axis to a list of strings for each month

x_axis = ["Jan", "Feb", "Mar", "Apr", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

#Set the y-axis to a list of floats as the total fare in US dollars is accumulated for each month

y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# Creates a scatter plot of values
plt.scatter( y_axis,x_axis, color="red", label="Chicago", )
#x axis
plt.xlabel('Dates')
#y axis
plt.ylabel('Fare($)')
#Title of the graph
plt.title("PyBer Fare by Month")
#Changing the order of dates on y
plt.gca().invert_yaxis()

#Set a limit up to 50 on x
plt.xlim(0,50)
#do I need to say it?
plt.legend()
plt.show()

# %%
#Create a Bubble Chart using the MATLAB method
plt.scatter(x_axis, y_axis, s=y_axis)

# %%
#making yaxis plots larger by 3
y_axis_larger = []
for data in y_axis:
    y_axis_larger.append(data*3)

# %%
#finalize making them big by adding the y_axis larger for the size parameter of the marker though Python
plt.scatter(x_axis, y_axis, s=y_axis_larger)
#MATLAB

# %%
##List comphrenesion to replace for and while looks ; Format for list comphrension is as follows:
#new_list = [expression for item in list if conditional]
plt.scatter(x_axis,y_axis, s=[i*3 for i in y_axis])

# %%
#Creating a scatter plot using the Object-Oriented Approach
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %%
#Creating a Bubble Chart using the Object-Oriented Interface , lets add an s to declare size of plots 
fig, ax = plt.subplots()
ax.scatter(x_axis,y_axis, s=y_axis)

# %%
#1. Change the color of the markers to sky blue.
fig, ax = plt.subplots()
ax.scatter(y_axis,x_axis,color="lightblue",s=[i*5 for i in y_axis],
           label="Boston", edgecolors= "black", linewidths=2)
#2.Change the size of the markers to 5 times each data point.

#3. Make the color 20% transparent.
alpha=0.2
#4. Add a black edge color to the circles.

#5. Make the linewidth of the circles 2 points.
linewidths=2,
#6.Add a legend for the city of Boston.
ax.legend(),
#7.Add a title.
plt.title("PyBer By Fare"),
#8.Switch the axis so that the Fare($) data is on the x-axis.
plt.gca().invert_yaxis()
#9.Add a limit for the x-axis data.
plt.xlim(0,50)
#10. Invert the y-axis so that January is at the top.
plt.ylabel('Dates')
plt.xlabel('Fare($)')
# Out:
# Text(0.5, 0, 'Fare($)')

# %%
#PieCharts only represent one dataset or category but are visually appealing
plt.pie(y_axis, labels=x_axis)
plt.show()

# %%
#values for pie and format; 
#the length of the tuple should be equal the numner of wedges of the radius 
#from the center of the pie for each wedge
#value specified to explode a wedge is the fraction from the center of the pie for each wedge
explode_values = (0,0,0,0,0,0,0.2,0,0,0,0,0) #to pop out the 7th month, July, we use 0.2
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%') 
#to add percentage of each wedge 
#we use autopct parameter and provide the format of 1 decimal place using .1f%
# Out:
# ([<matplotlib.patches.Wedge at 0x23e2d1f2d88>,
# ...
#  [Text(1.0940372721655667, 0.11437852557419124, 'Jan'),
#   Text(0.9905193092273052, 0.4784051609753622, 'Feb'),
#   Text(0.4998632656180861, 0.9798656620606842, 'Mar'),
#   Text(-0.3293082697128627, 1.0495504101750999, 'Apr'),
#   Text(-0.9306200792045569, 0.5864693241605263, 'May'),
#   Text(-1.0983369533258995, -0.06046434452452758, 'June'),
#   Text(-0.913463027456946, -0.9249785389235748, 'July'),
#   Text(-0.2333875250754619, -1.0749559354406817, 'Aug'),
#   Text(0.021097559209412746, -1.099797660024518, 'Sept'),
#   Text(0.4609812999807629, -0.9987473359504124, 'Oct'),
#   Text(0.8868706338501641, -0.6507384104340302, 'Nov'),
#   Text(1.0760953148482877, -0.22807646384834376, 'Dec')],
#  [Text(0.5967476029993999, 0.06238828667683158, '3.3%'),
#   Text(0.5402832595785301, 0.2609482696229248, '7.7%'),
#   Text(0.27265269033713785, 0.5344721793058277, '13.0%'),
#   Text(-0.17962269257065236, 0.5724820419136908, '11.7%'),
# ...

# %%
#Lets increase the size of the pie chart by using

#Assign 12 colors, one for each month
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange",
          "gold", "indianred", "tomato", "mistyrose"]
#pops out July - the 7th month of the year
explode_values = (0,0,0,0,0,0,0.2,0,0,0,0,0) 
#increase size of the piechart
plt.subplots(figsize=(8,8))
plt.pie(y_axis,
        #defining explode values in chart
       explode=explode_values,
        #defining colors
       colors=colors,
        #defining x axis
       labels=x_axis,
        #we use autopct parameter and provide the format of 1 decimal place using .1f%
       autopct='%.1f%%')

plt.show()

# %%
#running the code using object-oriented interface
fig, ax = plt.subplots()
ax.pie(y_axis,labels=x_axis)
plt.show()

# %%
#1. Add a percentage to one decimal place to each wedge of the pie.
#2. Increase the fig size to 8.8
fig, ax = plt.subplots(figsize=(8,8))
#7. Add new colors of your own choosing or use the colors from the previous pie chart.
colors = ["slateblue", "magenta", "lightblue", "green", 
          "yellowgreen", "greenyellow", "yellow", "orange", 
          "gold", "indianred", "tomato", "mistyrose"]
#3. Explode the two highest percentage months.
explode_values = (0,0,0.2,0,0,0,0.2,0,0,0,0,0) 
plt.pie(y_axis,
       explode=explode_values,
       colors=colors,
       #4. Add a shadow. 
        shadow=True,
        #5. Add a start angle so that January is at the top
        startangle=90,
        #6. Reverse the order so that the month order is in a clockwise direction
        counterclock=False,
        labels=x_axis,
        autopct='%.1f%%')
plt.show()

# %%
#Adding error bars can show either standard deviation, standard error, confidence intervals or min or max
#When added to a chart, they can show the variability of the plotted data, by looking at the error bars
#one can infer the significance of the data
#To create a line chart with error bars using the MATLAB approach, we use
plt.errorbar(x,y,yerr=<value)
#To the ride-sharing line chart, add the standard deviation of fare or yaxis as error bars
# %matplotlib inline
